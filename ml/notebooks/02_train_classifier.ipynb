# %% [markdown]
# # 02 - Train EfficientNet-B0 DR Classifier

# %%
import torch
import torch.nn as nn
from app.pipeline.classifier import DRClassifier

model = DRClassifier(num_classes=5)
print('EfficientNet-B0 classifier initialized.')

# %% [markdown]
# # CrossEntropyLoss with class weights, AdamW optimizer, CosineAnnealingLR
