# %% [markdown]
# # 08 - Clinical Validation & Benchmark Report

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix
print('Generating validation metrics: AUROC, Sensitivity, Specificity, ECE.')
