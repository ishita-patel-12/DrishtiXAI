# %% [markdown]
# # 01 - APTOS 2019 Data Preparation & Preprocessing

# %%
import os
import cv2
import numpy as np
import pandas as pd

print('Preparing APTOS 2019 dataset manifests...')

# %% [markdown]
# # Split data into Train (70%), Validation (15%), Test (15%)
# # Apply cropping and 512x512 resizing
