# %% [markdown]
# # 03 - Temperature Scaling Confidence Calibration

# %%
from app.pipeline.calibration import TemperatureCalibrator

calibrator = TemperatureCalibrator()
print(f'Temperature parameter T = {calibrator.temperature}')
